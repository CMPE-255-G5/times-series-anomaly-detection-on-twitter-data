# %% [markdown]
# <a href="https://colab.research.google.com/github/CMPE-255-G5/times-series-anomaly-detection-on-twitter-mention-volumes/blob/main/Twitter_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# packages
import kagglehub
import os
import pandas as pd

# %%
# Download latest version
path = kagglehub.dataset_download("julienjta/twitter-mentions-volumes")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 206k/206k [00:00<00:00, 43.4MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/julienjta/twitter-mentions-volumes/versions/1

# %%
# List files in the downloaded directory
print(os.listdir(path))
# Out:
# ['dataset.csv']

# %%
# Construct the full path to the dataset.csv file
file_path = os.path.join(path, 'dataset.csv')

# Load the CSV file into a pandas DataFrame
df = pd.read_csv(file_path)

# Display the first 5 rows of the DataFrame
display(df.head())
# Out:
#              timestamp  Apple  Amazon  Salesforce  CVS  Facebook  Google  \
# 0  2015-02-26 21:42:53    104    57.0          11  0.0      53.0    35.0
# 1  2015-02-26 21:47:53    100    43.0          10  0.0      64.0    41.0
# 2  2015-02-26 21:52:53     99    55.0           3  0.0      49.0    32.0
# 3  2015-02-26 21:57:53    154    64.0           4  0.0      48.0    36.0
# 4  2015-02-26 22:02:53    120    93.0           9  0.0      22.0    32.0
#
#     IBM  Coca-Cola  Pfizer  UPS
# 0   7.0        8.0     3.0  2.0
# 1   4.0        8.0     2.0  2.0
# 2  14.0        5.0     2.0  4.0
# 3   6.0       13.0    36.0  3.0
# 4   1.0       22.0     8.0  5.0

# %%
df.shape
# Out:
# (15902, 11)
